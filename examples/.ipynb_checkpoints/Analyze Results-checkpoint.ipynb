# %%
import pandas as pd
import matplotlib.pyplot as plt

results_df = pd.read_csv('noiselevels.csv')

# %%
result_dfs = list(results_df.groupby(['epoch', 's', 'num_clauses', 
                    'num_states', 'noise_level']).mean().reset_index().groupby(['s', 'num_clauses', 
                                                                                'num_states', 'noise_level']))

# %% [markdown]
# ## Summary of Results of All Parameters

# %%
summary_df = results_df[results_df['epoch']>40].groupby(['s', 'num_clauses', 
                                            'num_states', 'noise_level']).mean().reset_index()[['s', 'num_clauses', 
                                            'num_states', 'noise_level', 'accuracy']].sort_values('accuracy')
summary_df
# Out:
#         s  num_clauses  num_states  noise_level   accuracy
# 1     3.0          4.0        16.0         0.30  51.288800
# 37  100.0          4.0        16.0         0.30  51.586178
# 19   10.0          4.0        16.0         0.30  51.930133
# 39  100.0          4.0       256.0         0.30  52.295089
# 41  100.0          4.0     65536.0         0.30  52.375244
# 36  100.0          4.0        16.0         0.15  52.543600
# 7     3.0         10.0        16.0         0.30  52.632067
# 38  100.0          4.0       256.0         0.15  52.859533
# 40  100.0          4.0     65536.0         0.15  52.941111
# 43  100.0         10.0        16.0         0.30  52.966422
# 45  100.0         10.0       256.0         0.30  53.766756
# 47  100.0         10.0     65536.0         0.30  54.026800
# 42  100.0         10.0        16.0         0.15  54.771556
# 25   10.0         10.0        16.0         0.30  54.854867
# 46  100.0         10.0     65536.0         0.15  54.964422
# 44  100.0         10.0       256.0         0.15  55.128644
# 13    3.0        100.0        16.0         0.30  55.763711
# 18   10.0          4.0        16.0         0.15  59.740778
# 0     3.0          4.0        16.0         0.15  60.417578
# 49  100.0        100.0        16.0         0.30  64.406533
# 31   10.0        100.0        16.0         0.30  64.837378
# 51  100.0        100.0       256.0         0.30  66.422000
# 53  100.0        100.0     65536.0         0.30  66.611044
# 24   10.0         10.0        16.0         0.15  68.254244
# 6     3.0         10.0        16.0         0.15  70.744400
# 23   10.0          4.0     65536.0         0.30  70.781222
# 21   10.0          4.0       256.0         0.30  71.245844
# 50  100.0        100.0       256.0         0.15  72.780511
# 48  100.0        100.0        16.0         0.15  72.915400
# 52  100.0        100.0     65536.0         0.15  73.006778
# 22   10.0          4.0     65536.0         0.15  74.030889
# 20   10.0          4.0       256.0         0.15  74.758956
# 27   10.0         10.0       256.0         0.30  79.326800
# 29   10.0         10.0     65536.0         0.30  80.215222
# 26   10.0         10.0       256.0         0.15  81.777356
# 28   10.0         10.0     65536.0         0.15  82.513089
# 12    3.0        100.0        16.0         0.15  88.966489
# 35   10.0        100.0     65536.0         0.30  90.588933
# 33   10.0        100.0       256.0         0.30  91.069711
# 30   10.0        100.0        16.0         0.15  92.471644
# 5     3.0          4.0     65536.0         0.30  95.228889
# 34   10.0        100.0     65536.0         0.15  95.866022
# 32   10.0        100.0       256.0         0.15  95.897889
# 11    3.0         10.0     65536.0         0.30  96.438222
# 9     3.0         10.0       256.0         0.30  96.484467
# 17    3.0        100.0     65536.0         0.30  96.827044
# 3     3.0          4.0       256.0         0.30  97.015200
# 15    3.0        100.0       256.0         0.30  97.678911
# 16    3.0        100.0     65536.0         0.15  99.714044
# 4     3.0          4.0     65536.0         0.15  99.727111
# 10    3.0         10.0     65536.0         0.15  99.749467
# 14    3.0        100.0       256.0         0.15  99.904333
# 8     3.0         10.0       256.0         0.15  99.922578
# 2     3.0          4.0       256.0         0.15  99.944378

# %%
summary_df[summary_df['noise_level']==0.15].plot.bar(y='accuracy')
plt.show()

# %%
ax1 = None
ax2 = None
for vals, result_df in result_dfs:
    if vals[3] == 0.15:
        if ax1 == None:
            ax1 = result_df.plot(x='epoch', y='accuracy', label=vals)
        else:
            result_df.plot(x='epoch', y='accuracy', label=vals, ax=ax1)
    else:
        if ax2 == None:
            ax2 = result_df.plot(x='epoch', y='accuracy', label=vals)
        else:
            result_df.plot(x='epoch', y='accuracy', label=vals, ax=ax2)
plt.show()

# %% [markdown]
# ## View Effect of Noise Levels

# %%
ax1 = None
ax2 = None
for vals, result_df in result_dfs:
    if vals[1] == 100:
        if vals[3] == 0.15:
            if ax1 == None:
                ax1 = result_df.plot(x='epoch', y='accuracy', label=vals)
            else:
                result_df.plot(x='epoch', y='accuracy', label=vals, ax=ax1)
        else:
            if ax2 == None:
                ax2 = result_df.plot(x='epoch', y='accuracy', label=vals)
            else:
                result_df.plot(x='epoch', y='accuracy', label=vals, ax=ax2)
plt.show()

# %%
ax1 = None
for vals, result_df in result_dfs:
    if (vals[1] == 10) and (vals[0] == 3) and (vals[2] == 256):
        if ax1 == None:
            ax1 = result_df.plot(x='epoch', y='accuracy', label=vals[3])
        else:
            result_df.plot(x='epoch', y='accuracy', label=vals[3], ax=ax1)
plt.legend(bbox_to_anchor=(1,1), title="Noise Level")     
plt.title("Accuracy vs Training Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy %")
plt.savefig("accvsepoch.eps")
plt.show()

# %%
ax1 = None
for vals, result_df in result_dfs:
    #if (vals[1] == 10) and (vals[0] == 3) and (vals[2] == 256):
    if (vals[0] == 3) and (vals[1] == 10):
        if ax1 == None:
            ax1 = result_df.plot(x='epoch', y='accuracy', label="noise="+str(vals[3])+", s="+str(vals[0]))
        else:
            result_df.plot(x='epoch', y='accuracy', label="noise="+str(vals[3])+", states="+str(vals[2]), ax=ax1)
plt.legend(bbox_to_anchor=(1,1))   
plt.title("Accuracy vs Training Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy %")
plt.savefig("nstates_accvsepoch.eps")
plt.show()

# %% [markdown]
# ## View Average Effect of Parameters

# %%
fixed_params = {'num_clauses': 10,
               's': 3,
               'num_states': 256}
param_names = {'num_clauses': "Number of Clauses",
              'num_states': "Number of States",
              's': 's'}


def plot_param_effect(summary_df, param_name):
    secondary_params = [param for param in fixed_params.keys() if param != param_name]
    dfs = list(summary_df[summary_df['noise_level']==0.15].groupby(secondary_params))
    new_dfs = []
    for vals, df in dfs:
        df = df.sort_values(param_name)
        param_dict = {df.loc[idx, param_name]: [df.loc[idx, 'accuracy']] for idx in df.index}
        param_dict[secondary_params[0]] = [vals[0]]
        param_dict[secondary_params[1]] = [vals[1]]
        new_df = pd.DataFrame(param_dict)
        new_dfs.append(new_df)
    df_concat = pd.concat(new_dfs)
    
    # plot for first vs second param
    for secondary_param in secondary_params:
        secondary_param_name = param_names[secondary_param]
        third_param = [param for param in secondary_params if param != secondary_param][0]
        df_concat.loc[df_concat[third_param] == fixed_params[third_param], 
                      [coln for coln in df_concat.columns if coln != third_param]].plot.bar(x=secondary_param)
        plt.ylabel('Accuracy %')
        plt.xlabel(secondary_param_name)
        plt.title("Effect of Paramter "+str(param_names[param_name])+" and "+str(secondary_param_name))
        plt.legend(bbox_to_anchor=(1,1), title=param_names[param_name])
        plt.savefig(param_name+"_"+secondary_param+".eps")
        plt.show()

# %%
plot_param_effect(summary_df, 'num_clauses')

# %%
plot_param_effect(summary_df, 'num_states')
